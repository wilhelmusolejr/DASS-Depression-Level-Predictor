# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots


pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df=pd.read_csv('exercise_dataset.csv')

# %%
df.head()
# Out:
#   Activity, Exercise or Sport (1 hour)  130 lb  155 lb  180 lb  205 lb  \
# 0          Cycling, mountain bike, bmx     502     598     695     791
# 1  Cycling, <10 mph, leisure bicycling     236     281     327     372
# 2             Cycling, >20 mph, racing     944    1126    1308    1489
# 3          Cycling, 10-11.9 mph, light     354     422     490     558
# 4       Cycling, 12-13.9 mph, moderate     472     563     654     745
#
#    Calories per kg
# 0         1.750730
# 1         0.823236
# 2         3.294974
# 3         1.234853
# 4         1.647825

# %%
df.shape
# Out:
# (248, 6)

# %%
df.describe()
# Out:
#             130 lb       155 lb       180 lb       205 lb  Calories per kg
# count   248.000000   248.000000   248.000000   248.000000       248.000000
# mean    389.754032   464.689516   539.685484   614.620968         1.359930
# std     194.434028   232.019135   269.430029   306.847470         0.678851
# min      89.000000   106.000000   123.000000   140.000000         0.310067
# 25%     236.000000   281.000000   327.000000   372.000000         0.823236
# 50%     354.000000   422.000000   490.000000   558.000000         1.234853
# 75%     472.000000   563.000000   654.000000   745.000000         1.647825
# max    1062.000000  1267.000000  1471.000000  1675.000000         3.706591

# %%
df.isna().sum()
# Out:
# Activity, Exercise or Sport (1 hour)    0
# 130 lb                                  0
# 155 lb                                  0
# 180 lb                                  0
# 205 lb                                  0
# Calories per kg                         0
# dtype: int64

# %%
df.select_dtypes(include = ['int', 'float'])
# Out:
#      130 lb  155 lb  180 lb  205 lb  Calories per kg
# 0       502     598     695     791         1.750730
# 1       236     281     327     372         0.823236
# 2       944    1126    1308    1489         3.294974
# 3       354     422     490     558         1.234853
# 4       472     563     654     745         1.647825
# 5       590     704     817     931         2.059443
# 6       708     844     981    1117         2.471061
# 7       295     352     409     465         1.029722
# 8       177     211     245     279         0.617427
# 9       325     387     449     512         1.132626
# 10      413     493     572     651         1.441339
# 11      620     739     858     977         2.162348
# 12      738     880    1022    1163         2.574642
# 13      472     563     654     745         1.647825
# 14      207     246     286     326         0.721008
# 15      472     563     654     745         1.647825
# 16      354     422     490     558         1.234853
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 6 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Activity, Exercise or Sport (1 hour)  248 non-null    object
#  1   130 lb                                248 non-null    int64
#  2   155 lb                                248 non-null    int64
#  3   180 lb                                248 non-null    int64
#  4   205 lb                                248 non-null    int64
#  5   Calories per kg                       248 non-null    float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 11.8+ KB

# %%
df = df.rename (columns={'Activity, Exercise or Sport (1 hour)' : 'Activity'})
df = df.rename (columns={'Calories per kg' : 'Calories/kg'})
df = df.rename (columns={'130 lb' : '59kg', '155 lb' : '70kg', '180 lb' : '82kg', '205 lb' : '93kg'})
df.head()
# Out:
#                               Activity  59kg  70kg  82kg  93kg  Calories/kg
# 0          Cycling, mountain bike, bmx   502   598   695   791     1.750730
# 1  Cycling, <10 mph, leisure bicycling   236   281   327   372     0.823236
# 2             Cycling, >20 mph, racing   944  1126  1308  1489     3.294974
# 3          Cycling, 10-11.9 mph, light   354   422   490   558     1.234853
# 4       Cycling, 12-13.9 mph, moderate   472   563   654   745     1.647825

# %%
df1 = df.sort_values('Calories/kg', ascending=False)
df2 = df.sort_values('Calories/kg', ascending=False)
df1
# Out:
#                                       Activity  59kg  70kg  82kg  93kg  \
# 47            Running, 10.9 mph (5.5 min mile)  1062  1267  1471  1675
# 217               Cross country skiing, uphill   974  1161  1348  1536
# 46                Running, 10 mph (6 min mile)   944  1126  1308  1489
# 2                     Cycling, >20 mph, racing   944  1126  1308  1489
# 188                          Skin diving, fast   944  1126  1308  1489
# 45               Running, 9 mph (6.5 min mile)   885  1056  1226  1396
# 51                         Running, stairs, up   885  1056  1226  1396
# 212            Speed skating, ice, competitive   885  1056  1226  1396
# 216               Cross country skiing, racing   826   985  1144  1303
# 44               Running, 8.6 mph (7 min mile)   826   985  1144  1303
# 43               Running, 8 mph (7.5 min mile)   797   950  1103  1256
# 42                Running, 7.5mph (8 min mile)   738   880  1022  1163
# ...

# %%
data = np.arange(0,248,1)
df1.index = data
df1
# Out:
#                                       Activity  59kg  70kg  82kg  93kg  \
# 0             Running, 10.9 mph (5.5 min mile)  1062  1267  1471  1675
# 1                 Cross country skiing, uphill   974  1161  1348  1536
# 2                 Running, 10 mph (6 min mile)   944  1126  1308  1489
# 3                     Cycling, >20 mph, racing   944  1126  1308  1489
# 4                            Skin diving, fast   944  1126  1308  1489
# 5                Running, 9 mph (6.5 min mile)   885  1056  1226  1396
# 6                          Running, stairs, up   885  1056  1226  1396
# 7              Speed skating, ice, competitive   885  1056  1226  1396
# 8                 Cross country skiing, racing   826   985  1144  1303
# 9                Running, 8.6 mph (7 min mile)   826   985  1144  1303
# 10               Running, 8 mph (7.5 min mile)   797   950  1103  1256
# 11                Running, 7.5mph (8 min mile)   738   880  1022  1163
# ...

# %%
df2.index = data
df2.Activity = data
df2
# Out:
#      Activity  59kg  70kg  82kg  93kg  Calories/kg
# 0           0  1062  1267  1471  1675     3.706591
# 1           1   974  1161  1348  1536     3.397878
# 2           2   944  1126  1308  1489     3.294974
# 3           3   944  1126  1308  1489     3.294974
# 4           4   944  1126  1308  1489     3.294974
# 5           5   885  1056  1226  1396     3.089165
# 6           6   885  1056  1226  1396     3.089165
# 7           7   885  1056  1226  1396     3.089165
# 8           8   826   985  1144  1303     2.882679
# 9           9   826   985  1144  1303     2.882679
# 10         10   797   950  1103  1256     2.779774
# 11         11   738   880  1022  1163     2.574642
# 12         12   738   880  1022  1163     2.574642
# 13         13   738   880  1022  1163     2.574642
# 14         14   708   844   981  1117     2.471061
# 15         15   708   844   981  1117     2.471061
# 16         16   708   844   981  1117     2.471061
# ...

# %%
fig, ax = plt.subplots(figsize=[9, 7])

ax.plot(df1['59kg'],
         df1['Calories/kg'],
         )
ax.plot(df1['70kg'],
         df1['Calories/kg'],
         )
ax.plot(df1['82kg'],
         df1['Calories/kg'],
         )
ax.plot(df1['93kg'],
         df1['Calories/kg'],
         )
plt.xticks(rotation=60)
ax.set_xlabel('calories burned per hour')
ax.set_ylabel('Calories/kg')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig=make_subplots(specs=[[{"secondary_y":False}]])
fig.add_trace(go.Bar(x=df1['Activity'],y=df1['Calories/kg'],name=""),secondary_y=False,)
fig.update_layout(autosize=False,width=1200,height=800,title_text="Activity and Calories per kg")
fig.update_xaxes(title_text="Activity")
fig.update_yaxes(title_text="Calories",secondary_y=False)
fig.show()
# Out:
# <div>                            <div id="c9436c73-1ef0-447b-89d0-d9ee9526ff7e" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c9436c73-1ef0-447b-89d0-d9ee9526ff7e")) {                    Plotly.newPlot(                        "c9436c73-1ef0-447b-89d0-d9ee9526ff7e",                        [{"name":"","x":["Running, 10.9 mph (5.5 min mile)","Cross country skiing, uphill","Running, 10 mph (6 min mile)","Cycling, >20 mph, racing","Skin diving, fast","Running, 9 mph (6.5 min mile)","Running, stairs, up","Speed skating, ice, competitive","Cross country skiing, racing","Running, 8.6 mph (7 min mile)","Running, 8 mph (7.5 min mile)","Running, 7.5mph (8 min mile)","Skin diving, moderate","Stationary cycling, very vigorous","Cycling, 16-19 mph, very fast,
# ...

# %%
plt.scatter(df1.index, df1["59kg"])
plt.xlabel("Index (exercise)")
plt.ylabel("Calories burned")
plt.title("Scatter plot for calories burned vs exercise index (59kg)")
plt.show()

# %%
plt.scatter(df1.index, df1["70kg"])
plt.xlabel("Index (exercise)")
plt.ylabel("Calories burned")
plt.title("Scatter plot for calories burned vs exercise index (70kg)")
plt.show()

# %%
plt.scatter(df1.index, df1["82kg"])
plt.xlabel("Index (exercise)")
plt.ylabel("Calories burned")
plt.title("Scatter plot for calories burned vs exercise index (82kg)")
plt.show()

# %%
plt.scatter(df1.index, df1["93kg"])
plt.xlabel("Index (exercise)")
plt.ylabel("Calories burned")
plt.title("Scatter plot for calories burned vs exercise index (93kg)")
plt.show()

# %%
features=df2.columns[0:5]
features
# Out:
# Index(['Activity', '59kg', '70kg', '82kg', '93kg'], dtype='object')

# %%
target=df2.columns[-1:]
target
# Out:
# Index(['Calories/kg'], dtype='object')

# %% [markdown]
# # Scaling(Normalize)

# %%
from sklearn.preprocessing import StandardScaler
st_scaler=StandardScaler()
df2['st_scaled_59kg']= st_scaler.fit_transform(df2[['59kg']])
df2['st_scaled_70kg']= st_scaler.fit_transform(df2[['70kg']])
df2['st_scaled_82kg']= st_scaler.fit_transform(df2[['82kg']])
df2['st_scaled_93kg']= st_scaler.fit_transform(df2[['93kg']])
df2['st_scaled_Calories/kg']= st_scaler.fit_transform(df2[['Calories/kg']])
df2.head()
# Out:
#    Activity  59kg  70kg  82kg  93kg  Calories/kg  st_scaled_59kg  \
# 0         0  1062  1267  1471  1675     3.706591        3.464442
# 1         1   974  1161  1348  1536     3.397878        3.010931
# 2         2   944  1126  1308  1489     3.294974        2.856325
# 3         3   944  1126  1308  1489     3.294974        2.856325
# 4         4   944  1126  1308  1489     3.294974        2.856325
#
#    st_scaled_70kg  st_scaled_82kg  st_scaled_93kg  st_scaled_Calories/kg
# 0        3.464942        3.463600        3.462709               3.463803
# 1        3.007160        3.006158        3.008799               3.008125
# 2        2.856005        2.857396        2.855318               2.856232
# 3        2.856005        2.857396        2.855318               2.856232
# 4        2.856005        2.857396        2.855318               2.856232

# %%
from sklearn.preprocessing import MinMaxScaler
minmax = MinMaxScaler()
df2['minmax_scaled_Calories/kg']=minmax.fit_transform(df2[['Calories/kg']])
df2[['Calories/kg', 'st_scaled_Calories/kg', 'minmax_scaled_Calories/kg']]
# Out:
#      Calories/kg  st_scaled_Calories/kg  minmax_scaled_Calories/kg
# 0       3.706591               3.463803                   1.000000
# 1       3.397878               3.008125                   0.909109
# 2       3.294974               2.856232                   0.878812
# 3       3.294974               2.856232                   0.878812
# 4       3.294974               2.856232                   0.878812
# 5       3.089165               2.552447                   0.818218
# 6       3.089165               2.552447                   0.818218
# 7       3.089165               2.552447                   0.818218
# 8       2.882679               2.247662                   0.757425
# 9       2.882679               2.247662                   0.757425
# 10      2.779774               2.095769                   0.727128
# 11      2.574642               1.792983                   0.666733
# 12      2.574642               1.792983                   0.666733
# ...

# %%
#Plot histogram of raw data
df.hist(figsize=(10,9), ec="k")
plt.title('Calories/kg')
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Plot histogram of raw data
df2.hist(figsize=(10,9), ec="k")
plt.title('Dataset after minmax Scaling')
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Split the data into train and test dataset

# %%
from sklearn.model_selection import train_test_split
train, test=train_test_split(df2, test_size=0.2, random_state=42)
train.sample(5)
# Out:
#      Activity  59kg  70kg  82kg  93kg  Calories/kg  st_scaled_59kg  \
# 150       150   295   352   409   465     1.029722       -0.488318
# 37         37   590   704   817   931     2.059443        1.031974
# 213       213   177   211   245   279     0.617427       -1.096435
# 225       225   177   211   245   279     0.617427       -1.096435
# 134       134   354   422   490   558     1.234853       -0.184260
#
#      st_scaled_70kg  st_scaled_82kg  st_scaled_93kg  st_scaled_Calories/kg  \
# 150       -0.486673       -0.486025       -0.488593              -0.487406
# 37         1.033511        1.031345        1.033148               1.032520
# 213       -1.095610       -1.095948       -1.095983              -1.095976
# 225       -1.095610       -1.095948       -1.095983              -1.095976
# 134       -0.184363       -0.184783       -0.184898              -0.184620
#
#      minmax_scaled_Calories/kg
# 150                   0.211880
# 37                    0.515049
# ...

# %% [markdown]
# # Spot check algorithms and show evaluation metrics.

# %%
X_train = train[features]
y_train = train[target]
X_test = test[features]
y_test = test[target]

# %%
models = dict()
n_trees = 100
models['gb'] = GradientBoostingRegressor(n_estimators = n_trees)

# %%
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import GradientBoostingRegressor

from sklearn.model_selection import cross_val_score, KFold
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error
from numpy import mean
from numpy import std
import math

# %%
for name, model in models.items():
    cv = KFold(n_splits=5, shuffle=True, random_state=42)
    scores = cross_val_score(model, X_train, y_train, scoring = 'neg_root_mean_squared_error', cv=cv, n_jobs=-1, error_score='raise')
    print(name, '\n5-Fold Validation Scores:\n', scores)
    print('Cross Validation Average Score and StDev: %.3f (%.3f)\n' % (mean(scores), std(scores)))
# Out:
# gb
# 5-Fold Validation Scores:
#  [-0.02066102 -0.04816659 -0.01848353 -0.00737381 -0.05097099]
# Cross Validation Average Score and StDev: -0.029 (0.017)

# %% [markdown]
# # Train the models

# %%
results = dict()
models['gb'].fit(X_train,y_train)
predicted=model.predict(X_test)
rmse = mean_squared_error(predicted, y_test, squared = False)
print ('[',name,'] Root mean squared error is', rmse)
results[name]=rmse
# Out:
# [ gb ] Root mean squared error is 0.024696532165910366
# C:\Users\User\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %% [markdown]
# # Deploy trained model

# %%
import pickle
pickle.dump(models['gb'], open('model.pkl','wb'))

# %%
test_model = pickle.load(open('model.pkl','rb'))

# %%
new_Xdata = X_test.sample(10)
new_ydata = y_test.loc[new_Xdata.index.values]
print(new_Xdata)
print(new_ydata)
# Out:
#      Activity  59kg  70kg  82kg  93kg
# 183       183   236   281   327   372
# 238       238   148   176   204   233
# 45         45   590   704   817   931
# 246       246   118   141   163   186
# 6           6   885  1056  1226  1396
# 60         60   472   563   654   745
# 38         38   590   704   817   931
# 235       235   148   176   204   233
# 55         55   502   598   695   791
# 33         33   590   704   817   931
#      Calories/kg
# 183     0.823236
# 238     0.515199
# 45      2.059443
# 246     0.411618
# 6       3.089165
# 60      1.647825
# 38      2.059443
# 235     0.515199
# 55      1.750730
# 33      2.059443

# %%
pred=test_model.predict(new_Xdata)
print(pred)
# Out:
# [0.82324986 0.51525845 2.05941873 0.31020084 3.08910805 1.64781666
#  2.05941873 0.51525845 1.83638009 2.05941873]

# %%
print(new_ydata.values)
# Out:
# [[0.82323563]
#  [0.51519927]
#  [2.05944308]
#  [0.41161781]
#  [3.08916462]
#  [1.64782527]
#  [2.05944308]
#  [0.51519927]
#  [1.75072972]
#  [2.05944308]]

# %%
rmse = mean_squared_error(pred, new_ydata, squared = False)
print('Root mean Squared Error is', rmse)
# Out:
# Root mean Squared Error is 0.04197785235209484
